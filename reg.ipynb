# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load the dataset
path = 'D:\\USER\\MRINMAY\\'
df = pd.read_csv(path + 'Placement.csv')
print(df.head())
# Out:
#    cgpa  package
# 0  6.89      3.26
# 1  5.12      1.98
# 2  7.82      3.25
# 3  7.42      3.67
# 4  6.94      3.57

# %%
plt.scatter(df['cgpa'], df['package '], marker='o')
plt.xlabel('cgpa')
plt.ylabel('package ')
plt.title('Scatter Plot of CGPA vs Package')
plt.show()
